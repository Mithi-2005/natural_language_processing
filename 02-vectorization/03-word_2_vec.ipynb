# %% [markdown]
# ### Word2Vec

# %%
import gensim

# %%
from gensim.models import word2vec,keyedvectors

# %% [markdown]
# Download google word2vec form : https://drive.google.com/file/d/0B7XkCwpI5KDYNlNUTTlSS21pQmM/edit?resourcekey=0-wjGZdNAUop6WykTtMip30g

# %%
path = r"C:\Users\kvmit\gensim-data\word2vec-google-news-300\GoogleNews-vectors-negative300.bin.gz"

wv = keyedvectors.load_word2vec_format(path, binary=True)

vec_king = wv["king"]
print(vec_king.shape)   # (300,)
print(vec_king[:10])    # preview
# Out:
# (300,)
# [ 0.12597656  0.02978516  0.00860596  0.13964844 -0.02563477 -0.03613281
#   0.11181641 -0.19824219  0.05126953  0.36328125]

# %%
wv.save(r"D:\models\word2vec-google-news-300.kv")

# import os
# MODEL_DIR = r"D:\models"
# wv = KeyedVectors.load(os.path.join(MODEL_DIR, "word2vec-google-news-300.kv"))

# %%
import gensim.downloader as api
print(api.BASE_DIR)
# Out:
# C:\Users\kvmit/gensim-data

# %%
wv.most_similar('cricket')
# Out:
# [('cricketing', 0.8372225761413574),
#  ('cricketers', 0.8165745735168457),
#  ('Test_cricket', 0.8094819188117981),
#  ('Twenty##_cricket', 0.8068488240242004),
#  ('Twenty##', 0.7624265551567078),
#  ('Cricket', 0.75413978099823),
#  ('cricketer', 0.7372578382492065),
#  ('twenty##', 0.7316356897354126),
#  ('T##_cricket', 0.7304614186286926),
#  ('West_Indies_cricket', 0.6987985968589783)]

# %%
wv.most_similar('happy')
# Out:
# [('glad', 0.7408890724182129),
#  ('pleased', 0.6632170677185059),
#  ('ecstatic', 0.6626912355422974),
#  ('overjoyed', 0.6599286794662476),
#  ('thrilled', 0.6514049172401428),
#  ('satisfied', 0.6437949538230896),
#  ('proud', 0.636042058467865),
#  ('delighted', 0.627237856388092),
#  ('disappointed', 0.6269949674606323),
#  ('excited', 0.6247665286064148)]

# %%
wv.similarity('happy','sad')
# Out:
# 0.5354614

# %%
wv.similarity('happy','glad')
# Out:
# 0.74088913

# %%
vec=wv['king']-wv['man']+wv['woman']

# %%
wv.most_similar(vec)
# Out:
# [('king', 0.8449392318725586),
#  ('queen', 0.7300517559051514),
#  ('monarch', 0.645466148853302),
#  ('princess', 0.6156251430511475),
#  ('crown_prince', 0.5818676352500916),
#  ('prince', 0.5777117609977722),
#  ('kings', 0.5613663792610168),
#  ('sultan', 0.5376775860786438),
#  ('Queen_Consort', 0.5344247817993164),
#  ('queens', 0.5289887189865112)]
